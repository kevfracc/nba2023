# %%
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)

batting=pd.read_csv('mlb war players.csv', sep=',', header=0)
display(batting.head(100))




acuna
betts
judge
seager
ohtani
freeman
# Out:
#     RK              PLAYER   WAR  OFF  DEF  WAA  TRPG  ORPG   RAA  WAAWP
# 0  NaN       Shohei Ohtani  10.1  6.0 -1.1  7.4   9.5   8.1  72.6    1.2
# 1  NaN        Mookie Betts   8.4  7.5  0.9  6.4   5.1   4.7  65.0    0.5
# 2  NaN    Ronald Acuna Jr.   8.1  8.5 -0.8  6.0   5.1   4.7  61.7    0.5
# 3  NaN         Gerrit Cole   7.5  0.0  0.0  5.7   4.6   3.1  52.9    0.7
# 4  NaN       Marcus Semien   7.4  5.7  2.3  5.2   4.8   4.6  50.3    0.5
# 5  NaN          Matt Olson   7.4  6.6  0.0  5.2   5.0   4.7  52.7    0.5
# 6  NaN        Corey Seager   6.9  6.4  1.2  5.3   5.0   4.6  53.0    0.5
# 7  NaN     Freddie Freeman   6.6  7.5 -1.6  4.4   5.0   4.7  45.6    0.5
# 8  NaN    Gunnar Henderson   6.3  4.8  2.1  4.3   4.8   4.6  41.5    0.5
# 9  NaN         Blake Snell   6.0  0.0  0.0  4.5   4.7   3.4  40.5    0.6
# 10 NaN    Francisco Lindor   6.0  5.3  1.6  3.8   4.9   4.7  38.7    0.5
# 11 NaN        Austin Riley   5.9  5.0  1.3  3.7   4.9   4.7  37.4    0.5
# ...

# %%
batting[batting[['name_common','']]].sort_values(by=['combinedmargin']
                        , ascending=False #or True for players trending down
                        #, ascending=True
                       ).reset_index(drop=True).head(25)
